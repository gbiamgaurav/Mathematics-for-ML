# %% [markdown]
# <a href="https://colab.research.google.com/github/gbiamgaurav/Mathematics-for-ML/blob/main/Linear_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Dot Product

# %%
import numpy as np
import torch
import tensorflow as tf

# %%
x = np.array([2,3,5])

# %%
x
# Out:
# array([2, 3, 5])

# %%
xpt = torch.tensor([2,3,5.])
xtf = tf.Variable([2,3,5.])

# %%
y = x+1
y
# Out:
# array([3, 4, 6])

# %%
np.dot(x,y)
# Out:
# 48

# %%
2*3+3*4+5*6
# Out:
# 48

# %%
ypt = torch.tensor([9,6,5.])
ypt
# Out:
# tensor([9., 6., 5.])

# %%
xpt
# Out:
# tensor([2., 3., 5.])

# %%
torch.dot(xpt, ypt)
# Out:
# tensor(61.)

# %%
ytf = tf.Variable([9,6,5.])
ytf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=float32, numpy=array([9., 6., 5.], dtype=float32)>

# %%
xtf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=float32, numpy=array([2., 3., 5.], dtype=float32)>

# %%
tf.reduce_sum(tf.multiply(xtf, ytf))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=61.0>

# %%
tf.tensordot(xtf, ytf, 1)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=61.0>

# %% [markdown]
# ### Orthogonal Vectors

# %%
i = np.array([1,0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0,1])
j
# Out:
# array([0, 1])

# %%
np.dot(i,j)
# Out:
# 0

# %% [markdown]
# ### Transposition

# %%
import numpy as np
import torch
import tensorflow as tf

# %%
x = np.array([[2,3,5],[9,6,8]])
x
# Out:
# array([[2, 3, 5],
#        [9, 6, 8]])

# %%
x.T
# Out:
# array([[2, 9],
#        [3, 6],
#        [5, 8]])

# %%
xpt = torch.tensor([[2,3,5.],[9,6,8.]])
xpt
# Out:
# tensor([[2., 3., 5.],
#         [9., 6., 8.]])

# %%
xpt.T
# Out:
# tensor([[2., 9.],
#         [3., 6.],
#         [5., 8.]])

# %%
xtf = tf.Variable([[2,3,5.],[9,6,8.]])
xtf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[2., 3., 5.],
#        [9., 6., 8.]], dtype=float32)>

# %%
tf.transpose(xtf)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float32, numpy=
# array([[2., 9.],
#        [3., 6.],
#        [5., 8.]], dtype=float32)>

# %% [markdown]
# ### Arithmetic Operations

# %%
x = np.array([[2,3,5],[9,6,8]])
xpt = torch.tensor([[2,3,5.],[9,6,8.]])
xtf = tf.Variable([[2,3,5.],[9,6,8.]])

# %%
x
# Out:
# array([[2, 3, 5],
#        [9, 6, 8]])

# %%
xpt
# Out:
# tensor([[2., 3., 5.],
#         [9., 6., 8.]])

# %%
xtf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[2., 3., 5.],
#        [9., 6., 8.]], dtype=float32)>

# %%
x*2
# Out:
# array([[ 4,  6, 10],
#        [18, 12, 16]])

# %%
x+2
# Out:
# array([[ 4,  5,  7],
#        [11,  8, 10]])

# %%
xpt*2
# Out:
# tensor([[ 4.,  6., 10.],
#         [18., 12., 16.]])

# %%
xtf*2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 4.,  6., 10.],
#        [18., 12., 16.]], dtype=float32)>

# %%
xpt + 2
# Out:
# tensor([[ 4.,  5.,  7.],
#         [11.,  8., 10.]])

# %%
torch.add(xpt, 2)
# Out:
# tensor([[ 4.,  5.,  7.],
#         [11.,  8., 10.]])

# %%
xtf + 2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 4.,  5.,  7.],
#        [11.,  8., 10.]], dtype=float32)>

# %%
tf.add(xtf, 2)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 4.,  5.,  7.],
#        [11.,  8., 10.]], dtype=float32)>

# %%
xpt*2
# Out:
# tensor([[ 4.,  6., 10.],
#         [18., 12., 16.]])

# %%
torch.mul(xpt, 2)
# Out:
# tensor([[ 4.,  6., 10.],
#         [18., 12., 16.]])

# %%
xtf*2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 4.,  6., 10.],
#        [18., 12., 16.]], dtype=float32)>

# %%
tf.multiply(xtf, 2)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 4.,  6., 10.],
#        [18., 12., 16.]], dtype=float32)>

# %% [markdown]
# ### Hadamard Operations
#
# Element wise operations on matrices of same order

# %%
x = np.array([[2,3,5],[9,6,8]])
xpt = torch.tensor([[2,3,5.],[9,6,8.]])
xtf = tf.Variable([[2,3,5.],[9,6,8.]])

# %%
x
# Out:
# array([[2, 3, 5],
#        [9, 6, 8]])

# %%
xpt
# Out:
# tensor([[2., 3., 5.],
#         [9., 6., 8.]])

# %%
xtf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[2., 3., 5.],
#        [9., 6., 8.]], dtype=float32)>

# %%
y = x+4
y
# Out:
# array([[ 6,  7,  9],
#        [13, 10, 12]])

# %%
x
# Out:
# array([[2, 3, 5],
#        [9, 6, 8]])

# %%
x+y
# Out:
# array([[ 8, 10, 14],
#        [22, 16, 20]])

# %%
x*y
# Out:
# array([[ 12,  21,  45],
#        [117,  60,  96]])

# %%
y/x
# Out:
# array([[3.        , 2.33333333, 1.8       ],
#        [1.44444444, 1.66666667, 1.5       ]])

# %%
ypt = torch.add(xpt, 2)
ypt
# Out:
# tensor([[ 4.,  5.,  7.],
#         [11.,  8., 10.]])

# %%
xpt
# Out:
# tensor([[2., 3., 5.],
#         [9., 6., 8.]])

# %%
xpt+ypt
# Out:
# tensor([[ 6.,  8., 12.],
#         [20., 14., 18.]])

# %%
ypt/xpt
# Out:
# tensor([[2.0000, 1.6667, 1.4000],
#         [1.2222, 1.3333, 1.2500]])

# %%
ypt*xpt
# Out:
# tensor([[ 8., 15., 35.],
#         [99., 48., 80.]])

# %% [markdown]
# ### Reduction

# %%
x = np.array([[2,3,5],[9,6,8]])
xpt = torch.tensor([[2,3,5.],[9,6,8.]])
xtf = tf.Variable([[2,3,5.],[9,6,8.]])

# %%
x
# Out:
# array([[2, 3, 5],
#        [9, 6, 8]])

# %%
xpt
# Out:
# tensor([[2., 3., 5.],
#         [9., 6., 8.]])

# %%
xtf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[2., 3., 5.],
#        [9., 6., 8.]], dtype=float32)>

# %%
x.sum()
# Out:
# 33

# %%
torch.sum(xpt)
# Out:
# tensor(33.)

# %%
tf.reduce_sum(xtf)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=33.0>

# %%
x
# Out:
# array([[2, 3, 5],
#        [9, 6, 8]])

# %%
x.sum(axis=0)
# Out:
# array([11,  9, 13])

# %%
x.sum(axis=1)
# Out:
# array([10, 23])

# %%
torch.sum(xpt, 0)
# Out:
# tensor([11.,  9., 13.])

# %%
torch.sum(xpt, 1)
# Out:
# tensor([10., 23.])

# %%
tf.reduce_sum(xtf, 0)
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([11.,  9., 13.], dtype=float32)>

# %%
tf.reduce_sum(xtf, 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([10., 23.], dtype=float32)>

# %%
x
# Out:
# array([[2, 3, 5],
#        [9, 6, 8]])

# %%
x.min()
# Out:
# 2

# %%
torch.min(xpt)
# Out:
# tensor(2.)

# %%
tf.reduce_min(xtf)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.0>
