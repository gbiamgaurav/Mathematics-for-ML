# %% [markdown]
# <a href="https://colab.research.google.com/github/gbiamgaurav/Mathematics-for-ML/blob/main/Plotting%20of%20Equations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,1000)

# %%
x
# Out:
# array([-10.        ,  -9.97997998,  -9.95995996,  -9.93993994,
#         -9.91991992,  -9.8998999 ,  -9.87987988,  -9.85985986,
#         -9.83983984,  -9.81981982,  -9.7997998 ,  -9.77977978,
#         -9.75975976,  -9.73973974,  -9.71971972,  -9.6996997 ,
#         -9.67967968,  -9.65965966,  -9.63963964,  -9.61961962,
#         -9.5995996 ,  -9.57957958,  -9.55955956,  -9.53953954,
#         -9.51951952,  -9.4994995 ,  -9.47947948,  -9.45945946,
#         -9.43943944,  -9.41941942,  -9.3993994 ,  -9.37937938,
#         -9.35935936,  -9.33933934,  -9.31931932,  -9.2992993 ,
#         -9.27927928,  -9.25925926,  -9.23923924,  -9.21921922,
#         -9.1991992 ,  -9.17917918,  -9.15915916,  -9.13913914,
#         -9.11911912,  -9.0990991 ,  -9.07907908,  -9.05905906,
#         -9.03903904,  -9.01901902,  -8.998999  ,  -8.97897898,
#         -8.95895896,  -8.93893894,  -8.91891892,  -8.8988989 ,
#         -8.87887888,  -8.85885886,  -8.83883884,  -8.81881882,
# ...

# %%
y1 = 2*x+1
y2 = x+3

# %% [markdown]
# ![Untitled.jpg](data:image/jpeg;base64,...)

# %%
fig, axes = plt.subplots()

plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.axhline(y=0, color='lightgrey')
plt.axvline(x=0, color='lightgrey')

plt.axhline(y=5, linestyle='--')
plt.axvline(x=2, linestyle='--')

axes.set_xlim([-1,5])
axes.set_ylim([-1,7])

axes.plot(x,y1, color='green')
axes.plot(x,y2, color='blue');

# %%
y1 = 3*x+1
y2 = x+3

# %%
fig, axes = plt.subplots()

plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.axhline(y=0, color='lightgrey')
plt.axvline(x=0, color='lightgrey')

axes.set_xlim([-1,5])
axes.set_ylim([-1,7])

axes.plot(x,y1, color='green')
axes.plot(x,y2, color='blue');

# %%
y1 = 5*x + 6
y2 = 3*x + 1

# %%
fig, axes = plt.subplots()

plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.axhline(y=0, color='lightgrey')
plt.axvline(x=0, color='lightgrey')

plt.axhline(y=5, linestyle='--')
plt.axvline(x=2, linestyle='--')

axes.set_xlim([-1,5])
axes.set_ylim([-1,7])

axes.plot(x,y1, color='green')
axes.plot(x,y2, color='blue');
